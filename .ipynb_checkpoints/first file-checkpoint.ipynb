# %%
var('x,y')
A = solve(x^3+y^3,x)
A
# Out:
# [x == 1/2*y*(I*sqrt(3)*(-1)^(1/3) - (-1)^(1/3)), x == -1/2*y*(I*sqrt(3)*(-1)^(1/3) + (-1)^(1/3)), x == (-1)^(1/3)*y]

# %%
show(A)
# Out:
# [x == 1/2*y*(I*sqrt(3)*(-1)^(1/3) - (-1)^(1/3)), x == -1/2*y*(I*sqrt(3)*(-1)^(1/3) + (-1)^(1/3)), x == (-1)^(1/3)*y]

# %%
g = graphs.BubbleSortGraph(4)
show(g)
h = g.random_subgraph
show(h)
# Out:
# Graphics object consisting of 61 graphics primitives
# <bound method GenericGraph.random_subgraph of Bubble sort: Graph on 24 vertices>

# %%
G = graphs.RandomBarabasiAlbert(12,3)
show(G)
# Out:
# Graphics object consisting of 40 graphics primitives
